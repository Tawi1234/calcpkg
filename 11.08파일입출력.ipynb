# %% [markdown]
# # 파일 입출력 file Handling
#
# - CRUD
#   - Create
#   - Read
#   - Update
#   - Delete

# %%
open('file_path(파일경로)', 
     'access_mode(접근모드)')

# %% [markdown]
# - 파일모드
#  - w : 쓰기
#  - r : 읽기
#  - a : 추가
#  - b : 바이너리
#  - x : 단독 생성용 파일 열기(파일 없는 경우만)

# %%
# 텍스트 파일 만들기
fp = open('sales.txt', 'x')
fp.close()

# %%
# 텍스트 파일 쓰기
fp = open('sales_2.txt', 'w')
fp.write('frist file')
fp.close()

# %%
## 경로를 지정하지 않으면 현재 작업 디렉토리에 파일 생성
## 상대 경로 : 현재 작업 디랙토리 기준
# 절대경로 : 저장 장치 디스크에서 파일의 위치

# %%
import os
os.getcwd()
# Out:
# 'c:\\Users\\601\\Desktop\\python'

# %%
fp = open(r"c:Users\\601\\Desktop\\python", 'w')
fp.write('frist_file')
fp.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [34], line 1
# ----> 1 fp = open(r"c:Users\\601\\Desktop\\python", 'w')
#       2 fp.write('frist_file')
#       3 fp.close()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\IPython\core\interactiveshell.py:282, in _modified_open(file, *args, **kwargs)
#     275 if file in {0, 1, 2}:
#     276     raise ValueError(
#     277         f"IPython won't let you open fd={file} by default "
#     278         "as it is likely to crash IPython. If you know what you are doing, "
#     279         "you can use builtins' open."
#     280     )
# --> 282 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'c:Users\\\\601\\\\Desktop\\\\python'

# %%
import os

os.listdir()
# Out:
# ['11.08파일입출력.ipynb', 'sales.txt', 'sales_2.txt']

# %%
# 직접 디렉토리에 들어가서 확인하기
# os.listdir()로 나열하여 확인하기
# os.path.isfile()로 존재여부 확인하기

os.path.isfile("sales.txt")
# Out:
# True

# %%
#파일 열기
fp = open("/content/sales.txt")
print("fp".read())
fp.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [31], line 2
#       1 #파일 열기
# ----> 2 fp = open("/content/sales.txt")
#       3 print("fp".read())
#       4 fp.close()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\IPython\core\interactiveshell.py:282, in _modified_open(file, *args, **kwargs)
#     275 if file in {0, 1, 2}:
#     276     raise ValueError(
#     277         f"IPython won't let you open fd={file} by default "
#     278         "as it is likely to crash IPython. If you know what you are doing, "
#     279         "you can use builtins' open."
#     280     )
# --> 282 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/sales.txt'

# %%
help(open)
# encoding=None 한글 사용시 encoding 적용

# %%
#한글 인코딩 불러오기가 안될 경우
# 대표적으로 사옹하는 encoding
# ' utf-8' 'euc-kr' 'cp949'11.08파일입출력.ipynb

# %%
# with open("파일명", "모드") as f:
# # 코드블록(들여쓰기 내부)
# # 블록을 떠나면, 파일이 자동으로 닫힙니다.
# # 자동으로 닫힌 파일은 리소스가 해제됩니다.
# # 캡슐화가 됩니다.

# %%
# 파일 읽기
with open("sales_2.txt", "r") as f:
    for i in range(2):
    line = f.readline()
    lines.append(line)
print(lines)

# %%
#readlines 여러 줄 읽기 > 리스트로
with open("sales_2.txt", "r") as f:
    lines.append(line)
print(lines)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [30], line 3
#       1 #readlines 여러 줄 읽기 > 리스트로
#       2 with open("sales_2.txt", "r") as f:
# ----> 3     lines.append(line)
#       4 print(lines)
#
# NameError: name 'lines' is not defined

# %%
fp = open('sales.txt', 'x')
fp.close()

# %%
def my_function():
    print("모듈 내에 있는 함수")

my_variable = "모듈 내에 있는 함수"

print("my_m",__name__)
print("out.py",__name__)

# %%
from my_package import my_m

print(__name__)
print(my_m,__name__)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [3], line 1
# ----> 1 from my_package import my_m
#       3 print(__name__)
#       4 print(my_m,__name__)
#
# ModuleNotFoundError: No module named 'my_package'
